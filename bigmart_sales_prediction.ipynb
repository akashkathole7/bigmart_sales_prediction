# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
from matplotlib import pyplot as plt

plt.style.use("fivethirtyeight")
sns.set_style("white")

# %%
data = pd.read_csv("/content/Train.csv")

# %%
colors1 = ['#e6ccb2','#b08968','#7f5539'] 
colors2 = ['#ede0d4','#e6ccb2','#ddb892','#b08968','#7f5539','#9c6644','#dda15e']

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight  ...        Outlet_Type  Item_Outlet_Sales
# 0           FDA15         9.30  ...  Supermarket Type1          3735.1380
# 1           DRC01         5.92  ...  Supermarket Type2           443.4228
# 2           FDN15        17.50  ...  Supermarket Type1          2097.2700
# 3           FDX07        19.20  ...      Grocery Store           732.3800
# 4           NCD19         8.93  ...  Supermarket Type1           994.7052
#
# [5 rows x 12 columns]

# %%
data.shape
# Out:
# (8523, 12)

# %%
data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
list(data.columns)
# Out:
# ['Item_Identifier',
#  'Item_Weight',
#  'Item_Fat_Content',
#  'Item_Visibility',
#  'Item_Type',
#  'Item_MRP',
#  'Outlet_Identifier',
#  'Outlet_Establishment_Year',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type',
#  'Item_Outlet_Sales']

# %%
data['Item_Weight'].mean()
# Out:
# 12.85764518413634

# %%
data['Item_Weight'] = data['Item_Weight'].fillna(data['Item_Weight'])

# %%
data['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
data['Outlet_Size'].mode()
# Out:
# 0    Medium
# dtype: object

# %%
data['Outlet_Size'] = data['Outlet_Size'].fillna("Medium")

# %%
data.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight  ...        Outlet_Type  Item_Outlet_Sales
# 0           FDA15    12.857645  ...  Supermarket Type1          3735.1380
# 1           DRC01    12.857645  ...  Supermarket Type2           443.4228
# 2           FDN15    12.857645  ...  Supermarket Type1          2097.2700
# 3           FDX07    12.857645  ...      Grocery Store           732.3800
# 4           NCD19    12.857645  ...  Supermarket Type1           994.7052
#
# [5 rows x 12 columns]

# %%
sns.countplot(data['Item_Fat_Content'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
def cat_unmarited_analysis(feature):
  plot = sns.countplot(data[feature])
  plot.set_xticklabels(plot.get_xticklabels(),rotation = 50)


  data_ = data[feature].value_counts().sort_values(ascending = True)
  plt.figure(figsize = (20,5),facecolor = 'white')
  plt.subplot(1,2,1)
  plt.barh(y = data_.index,width = data_.values,
           linewidth =1,height = 0.7,
           color = colors2,edgecolor = 'k')
  


  sns.despine()
  ax = plt.subplot(1,2,2)
  ax.pie(x = data_.values,labels = data_.index,
         radius = 1.2,shadow = True,
         colors = colors2,autopct = "%1.1f%%",
         explode = [0.04 for i in range(data[feature].nunique())])
  ax.add_artist(plt.Circle((0,0),0.04 ,fc = 'white'))
  plt.suptitle(t = feature,fontweight = 'bold')
  plt.show()

# %%
data.replace({'Item_Fat_Content':{'low fat':'Low Fat','LF':"Low Fat"}},inplace = True)

# %%
cat_unmarited_analysis('Item_Fat_Content')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
cat_unmarited_analysis("Item_Type")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
cat_unmarited_analysis('Outlet_Identifier')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
cat_unmarited_analysis("Outlet_Establishment_Year")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
cat_unmarited_analysis("Outlet_Size")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
cat_unmarited_analysis("Outlet_Location_Type")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
cat_unmarited_analysis('Outlet_Type')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.displot(data['Item_MRP'],kde = True)
plt.show()

# %%
list(data.columns)
# Out:
# ['Item_Identifier',
#  'Item_Weight',
#  'Item_Fat_Content',
#  'Item_Visibility',
#  'Item_Type',
#  'Item_MRP',
#  'Outlet_Identifier',
#  'Outlet_Establishment_Year',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type',
#  'Item_Outlet_Sales']

# %%
sns.displot(data['Item_Visibility'],kde = True)
plt.show()

# %%
sns.displot(data['Item_Outlet_Sales'],kde = True)
plt.show()

# %%
data.head()
# Out:
#    Item_Identifier  Item_Weight  ...        Outlet_Type  Item_Outlet_Sales
# 0              156         9.30  ...  Supermarket Type1          3735.1380
# 1                8         5.92  ...  Supermarket Type2           443.4228
# 2              662        17.50  ...  Supermarket Type1          2097.2700
# 3             1121        19.20  ...      Grocery Store           732.3800
# 4             1297         8.93  ...  Supermarket Type1           994.7052
#
# [5 rows x 12 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
data['Item_Fat_Content'] = encoder.fit_transform(data['Item_Fat_Content'])
data['Item_Identifier'] = encoder.fit_transform(data['Item_Identifier'])
data['Item_Type'] = encoder.fit_transform(data['Item_Type'])
data['Outlet_Identifier'] = encoder.fit_transform(data['Outlet_Identifier'])
data['Outlet_Size'] = encoder.fit_transform(data['Outlet_Size'])
data['Outlet_Location_Type'] = encoder.fit_transform(data['Outlet_Location_Type'])
data['Outlet_Type'] = encoder.fit_transform(data['Outlet_Type'])

# %%
data.head()
# Out:
#    Item_Identifier  Item_Weight  ...  Outlet_Type  Item_Outlet_Sales
# 0              156         9.30  ...            1          3735.1380
# 1                8         5.92  ...            2           443.4228
# 2              662        17.50  ...            1          2097.2700
# 3             1121        19.20  ...            0           732.3800
# 4             1297         8.93  ...            1           994.7052
#
# [5 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   int64
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   int64
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   int64
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   int64
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   int64
#  9   Outlet_Location_Type       8523 non-null   int64
#  10  Outlet_Type                8523 non-null   int64
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(8)
# memory usage: 799.2 KB

# %%
X = data.drop(columns = ['Item_Outlet_Sales'],axis = 1)

# %%
Y = data['Item_Outlet_Sales']

# %%
print(X)
# Out:
#       Item_Identifier  Item_Weight  ...  Outlet_Location_Type  Outlet_Type
# 0                 156        9.300  ...                     0            1
# 1                   8        5.920  ...                     2            2
# 2                 662       17.500  ...                     0            1
# 3                1121       19.200  ...                     2            0
# 4                1297        8.930  ...                     2            1
# ...               ...          ...  ...                   ...          ...
# 8518              370        6.865  ...                     2            1
# 8519              897        8.380  ...                     1            1
# 8520             1357       10.600  ...                     1            1
# 8521              681        7.210  ...                     2            2
# 8522               50       14.800  ...                     0            1
#
# [8523 rows x 11 columns]

# %%
print(Y)
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
#           ...
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2,random_state = 1)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (8523, 11) (6818, 11) (1705, 11)

# %%
from xgboost import XGBRegressor

# %%
model = XGBRegressor()

# %%
model.fit(X_train,Y_train)
# Out:
# [15:58:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor()

# %%
train_predict = model.predict(X_train)

# %%
from sklearn import metrics

# %%
metrics.r2_score(Y_train,train_predict)
# Out:
# 0.635705706139352

# %%
plt.scatter(x = train_predict ,y = Y_train,color= 'red')
plt.show()
